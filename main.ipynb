# %%
# !pip install overrides numpy termcolor torch==1.4.0 torchvision==0.7.0 pythainlp
# Out:
# Requirement already satisfied: overrides in /usr/local/lib/python3.6/dist-packages (3.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (1.19.4)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.6/dist-packages (1.1.0)
# Requirement already satisfied: torch==1.4.0 in /usr/local/lib/python3.6/dist-packages (1.4.0)
# Requirement already satisfied: torchvision==0.7.0 in /usr/local/lib/python3.6/dist-packages (0.7.0)
# Requirement already satisfied: pythainlp in /usr/local/lib/python3.6/dist-packages (2.2.6)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.7.0) (7.0.0)
# Requirement already satisfied: tinydb>=3.0 in /usr/local/lib/python3.6/dist-packages (from pythainlp) (4.3.0)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.6/dist-packages (from pythainlp) (2.23.0)
# Requirement already satisfied: python-crfsuite>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from pythainlp) (0.9.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.22.0->pythainlp) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.22.0->pythainlp) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.22.0->pythainlp) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.22.0->pythainlp) (3.0.4)

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
import sys
sys.path.append('/content/gdrive/MyDrive/thesis/ner_incomplete_annotation/')

# %%
import os
DATA_PATH = '/content/gdrive/MyDrive/thesis/ner_incomplete_annotation/'
os.chdir(DATA_PATH)

# %%
class Struct:
    def __init__(self, **entries):
        self.__dict__.update(entries)

def get_config():
    ###Training Hyperparameters
    # parser.add_argument('--device', type=str, default="cpu", choices=['cpu', 'cuda:0', 'cuda:1', 'cuda:2'],
    #                     help="GPU/CPU devices")
    # parser.add_argument('--seed', type=int, default=42, help="random seed")
    # parser.add_argument('--digit2zero', action="store_true", default=True,
    #                     help="convert the number to 0, make it true is better")
    # parser.add_argument('--dataset', type=str, default="conll2003")
    # parser.add_argument('--embedding_file', type=str, default=DATA_PATH + "data/glove.6B.100d.txt",
    #                     help="we will be using random embeddings if file do not exist")
    # parser.add_argument('--embedding_dim', type=int, default=100)
    # parser.add_argument('--optimizer', type=str, default="sgd")
    # parser.add_argument('--learning_rate', type=float, default=0.01)  ##only for sgd now
    # parser.add_argument('--momentum', type=float, default=0.0)
    # parser.add_argument('--l2', type=float, default=1e-8)
    # parser.add_argument('--lr_decay', type=float, default=0)
    # parser.add_argument('--batch_size', type=int, default=10, help="default batch size is 10 (works well)")
    # parser.add_argument('--num_epochs', type=int, default=100, help="Usually we set to 10.")
    # parser.add_argument('--train_num', type=int, default=-1, help="-1 means all the data")
    # parser.add_argument('--dev_num', type=int, default=-1, help="-1 means all the data")
    # parser.add_argument('--test_num', type=int, default=-1, help="-1 means all the data")
    # parser.add_argument('--entity_keep_ratio', type= float, default=0.5, help="the percentage of entities to be kept", choices=np.arange(0, 1.1, 0.1))
    # parser.add_argument('--num_outer_iterations', type= int , default= 10, help="Number of outer iterations for cross validation")


    ##model hyperparameter
    # parser.add_argument('--variant', type=str, default="hard", choices=["hard", "soft"], help="The hard or soft variant of the model")
    # parser.add_argument('--model_folder', type=str, default="english_model", help="The name to save the model files")
    # parser.add_argument('--hidden_dim', type=int, default=200, help="hidden size of the LSTM")
    # parser.add_argument('--dropout', type=float, default=0.5, help="dropout for embedding")
    # parser.add_argument('--use_char_rnn', type=int, default=1, choices=[0, 1], help="use character-level lstm, 0 or 1")
    # parser.add_argument('--context_emb', type=str, default="none", choices=["none", "elmo"],
    #                     help="contextual word embedding")

    options = {
        'device': 'cuda:0',
        'seed': 42,
        'digit2zero': True,
        'dataset': "dataset",
        'embedding_file': DATA_PATH + "data/glove.6B.100d.txt",
        'embedding_dim': 100,
        'optimizer': 'sgd',
        'learning_rate': 0.001,
        'momentum': 0.0,
        'l2': 1e-8,
        'lr_decay': 0,
        'batch_size': 10,
        'num_epochs': 100,
        'train_num': -1,
        'dev_num': -1,
        'test_num': -1,
        'entity_keep_ratio': 0,
        'num_outer_iterations': 10,

        'variant': 'hard',
        'model_folder': 'english_model',
        'hidden_dim': 200,
        'dropout': 0.5,
        'use_char_rnn': 1,
        'context_emb': 'none',
    }

    args = Struct(**options)
    return args

# %%
import argparse
import random
import numpy as np
from typing import Tuple
from config import Reader, Config, ContextEmb, lr_decay, simple_batching, evaluate_batch_insts, get_optimizer, write_results, batching_list_instances
from config import remove_entites
import time
from model.neuralcrf import NNCRF
import torch
from typing import List
from common import Instance
from termcolor import colored
import os
from config.utils import load_elmo_vec
import pickle
import tarfile
import shutil
import math
import itertools


def set_seed(opt, seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if opt.device.startswith("cuda"):
        print("using GPU...", torch.cuda.current_device())
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)


def train_model(config: Config, train_insts: List[List[Instance]], dev_insts: List[Instance], test_insts: List[Instance]):
    train_num = sum([len(insts) for insts in train_insts])
    print("[Training Info] number of training instances: %d" % (train_num))

    dev_batches = batching_list_instances(config, dev_insts)
    test_batches = batching_list_instances(config, test_insts)

    model_folder = config.model_folder
    res_folder = "results"
    # if os.path.exists(model_folder):
    #     raise FileExistsError(f"The folder {model_folder} exists. Please either delete it or create a new one "
    #                           f"to avoid override.")

    print("[Training Info] The model will be saved to: %s.tar.gz" % (model_folder))
    if not os.path.exists(model_folder):
        os.makedirs(model_folder)
    if not os.path.exists(res_folder):
        os.makedirs(res_folder)

    num_outer_iterations = config.num_outer_iterations
    for iter in range(num_outer_iterations):
        print(f"[Training Info] Running for {iter}th large iterations.")
        model_names = [] #model names for each fold
        train_batches = [batching_list_instances(config, insts) for insts in train_insts]
        for fold_id, folded_train_insts in enumerate(train_insts):
            print(f"[Training Info] Training fold {fold_id}.")
            model_name = model_folder + f"/lstm_crf_{fold_id}.m"
            model_names.append(model_name)
            train_one(config=config, train_batches = train_batches[fold_id],
                      dev_insts=dev_insts, dev_batches=dev_batches, model_name=model_name)

        # assign hard prediction to other folds
        if config.variant == "hard":
            print("\n\n[Data Info] Assigning labels for the HARD approach")
        else:
            print("\n\n[Data Info] Performing marginal decoding to assign the marginals")

        for fold_id, folded_train_insts in enumerate(train_insts):
            model = NNCRF(config)
            model_name = model_names[fold_id]
            model.load_state_dict(torch.load(model_name))
            predict_with_constraints(config=config, model=model,
                                     fold_batches = train_batches[1-fold_id],
                                     folded_insts= train_insts[1 - fold_id])  ## set a new label id

        print("\n\n")

        print("[Training Info] Training the final model" )
        all_train_insts = list(itertools.chain.from_iterable(train_insts))
        model_name = model_folder + "/final_lstm_crf.m"
        config_name = model_folder + "/config.conf"
        res_name = res_folder + "/lstm_crf.results".format()
        all_train_batches = batching_list_instances(config= config, insts=all_train_insts)
        model = train_one(config = config, train_batches=all_train_batches, dev_insts=dev_insts, dev_batches=dev_batches,
                          model_name=model_name, config_name=config_name,test_insts=test_insts, test_batches=test_batches,result_filename=res_name)
        print("Archiving the best Model...")
        with tarfile.open(model_folder + "/" + model_folder + ".tar.gz", "w:gz") as tar:
            tar.add(model_folder, arcname=os.path.basename(model_folder))
        # print("The best dev: %.2f" % (best_dev[0]))
        # print("The corresponding test: %.2f" % (best_test[0]))
        # print("Final testing.")
        model.load_state_dict(torch.load(model_name))
        model.eval()
        evaluate_model(config, model, test_batches, "test", test_insts)
        write_results(res_name, test_insts)


def predict_with_constraints(config: Config, model: NNCRF, fold_batches: List[Tuple], folded_insts:List[Instance]):
    batch_id = 0
    batch_size = config.batch_size
    model.eval()
    for batch in fold_batches:
        one_batch_insts = folded_insts[batch_id * batch_size:(batch_id + 1) * batch_size]
        word_seq_lens = batch[1].cpu().numpy()
        if config.variant == "hard":
            with torch.no_grad():
                batch_max_scores, batch_max_ids = model.decode(batch)
            batch_max_ids = batch_max_ids.cpu().numpy()
            for idx in range(len(batch_max_ids)):
                length = word_seq_lens[idx]
                prediction = batch_max_ids[idx][:length].tolist()
                prediction = prediction[::-1]
                one_batch_insts[idx].output_ids = prediction
        else:
            ## means soft model, assign soft probabilit
            with torch.no_grad():
                marginals = model.get_marginal(batch)
            marginals = marginals.cpu().numpy()
            for idx in range(len(marginals)):
                length = word_seq_lens[idx]
                one_batch_insts[idx].marginals = marginals[idx, :length, :]
        batch_id += 1


def train_one(config: Config, train_batches: List[Tuple], dev_insts: List[Instance],
              dev_batches: List[Tuple], model_name: str, test_insts: List[Instance] = None,
              test_batches: List[Tuple] = None, config_name: str = None, result_filename: str = None) -> NNCRF:
    model = NNCRF(config)
    model.train()
    optimizer = get_optimizer(config, model)
    epoch = config.num_epochs
    best_dev_f1 = -1
    saved_test_metrics = None
    for i in range(1, epoch + 1):
        epoch_loss = 0
        start_time = time.time()
        model.zero_grad()
        if config.optimizer.lower() == "sgd":
            optimizer = lr_decay(config, optimizer, i)
        for index in np.random.permutation(len(train_batches)):
            model.train()
            loss = model(*train_batches[index])
            epoch_loss += loss.item()
            loss.backward()
            optimizer.step()
            model.zero_grad()
        end_time = time.time()
        print("Epoch %d: %.5f, Time is %.2fs" % (i, epoch_loss, end_time - start_time), flush=True)

        model.eval()
        # metric is [precision, recall, f_score]
        dev_metrics = evaluate_model(config, model, dev_batches, "dev", dev_insts)
        if test_insts is not None:
            test_metrics = evaluate_model(config, model, test_batches, "test", test_insts)
        if dev_metrics[2] > best_dev_f1:
            print("saving the best model...")
            best_dev_f1 = dev_metrics[2]
            if test_insts is not None:
                saved_test_metrics = test_metrics
            torch.save(model.state_dict(), model_name)
            # # Save the corresponding config as well.
            if config_name:
                f = open(config_name, 'wb')
                pickle.dump(config, f)
                f.close()
            if result_filename:
                write_results(result_filename, test_insts)
        model.zero_grad()
    if test_insts is not None:
        print(f"The best dev F1: {best_dev_f1}" )
        print(f"The corresponding test: {saved_test_metrics}")
    return model

def evaluate_model(config: Config, model: NNCRF, batch_insts_ids, name: str, insts: List[Instance]):
    ## evaluation
    metrics = np.asarray([0, 0, 0], dtype=int)
    batch_id = 0
    batch_size = config.batch_size
    for batch in batch_insts_ids:
        one_batch_insts = insts[batch_id * batch_size:(batch_id + 1) * batch_size]
        with torch.no_grad():
            batch_max_scores, batch_max_ids = model.decode(batch)
        metrics += evaluate_batch_insts(batch_insts=one_batch_insts,
                                        batch_pred_ids = batch_max_ids,
                                        batch_gold_ids=batch[-1],
                                        word_seq_lens= batch[1], idx2label=config.idx2labels)
        batch_id += 1
    p, total_predict, total_entity = metrics[0], metrics[1], metrics[2]
    precision = p * 1.0 / total_predict * 100 if total_predict != 0 else 0
    recall = p * 1.0 / total_entity * 100 if total_entity != 0 else 0
    fscore = 2.0 * precision * recall / (precision + recall) if precision != 0 or recall != 0 else 0
    print("[%s set] Precision: %.2f, Recall: %.2f, F1: %.2f" % (name, precision, recall, fscore), flush=True)
    return [precision, recall, fscore]

# %%
opt = get_config()
conf = Config(opt)

reader = Reader(conf.digit2zero)
set_seed(opt, conf.seed)

trains = reader.read_txt(conf.train_file, conf.train_num)
devs = reader.read_txt(conf.dev_file, conf.dev_num)
tests = reader.read_txt(conf.test_file, conf.test_num)

if conf.context_emb != ContextEmb.none:
    print('[Data Info] Loading the ELMo vectors for all datasets.')
    conf.context_emb_size = load_elmo_vec(conf.train_file + "." + conf.context_emb.name + ".vec", trains)
    load_elmo_vec(conf.dev_file + "." + conf.context_emb.name + ".vec", devs)
    load_elmo_vec(conf.test_file + "." + conf.context_emb.name + ".vec", tests)

conf.use_iobes(trains + devs + tests)
conf.build_label_idx(trains + devs + tests)

conf.build_word_idx(trains, devs, tests)
conf.build_emb_table()
conf.map_insts_ids(devs + tests)
print("[Data Info] num chars: " + str(conf.num_char))
print("[Data Info] num words: " + str(len(conf.word2idx)))

print(f"[Data Info] Removing {conf.entity_keep_ratio*100}% of entities from the training set")

print("[Data Info] Removing the entities")
## it will return the set of removed entities (for debug purpose)
_ = remove_entites(trains, conf)
# print(f"entities removed: {span_set}")
conf.map_insts_ids(trains)
random.shuffle(trains)
for inst in trains:
    inst.is_prediction = [False] * len(inst.input)
    if conf.variant == "soft":
        inst.marginals = np.full((len(inst.input), conf.label_size), -1e10)
    for pos, label in enumerate(inst.output):
        if label == conf.O:
            inst.is_prediction[pos] = True
        if conf.variant == "soft":
            inst.marginals[pos, conf.label2idx[label]] = 0

num_insts_in_fold = math.ceil(len(trains) / conf.num_folds)
trains = [trains[i * num_insts_in_fold: (i + 1) * num_insts_in_fold] for i in range(conf.num_folds)]
train_model(config=conf, train_insts=trains, dev_insts=devs, test_insts=tests)
# Out:
# 100%|██████████| 101100/101100 [00:00<00:00, 589438.11it/s]
# using GPU... 0
# Reading file: data/dataset/train.txt
# 100%|██████████| 12949/12949 [00:00<00:00, 503654.09it/s]
# number of sentences: 400
# Reading file: data/dataset/dev.txt
# number of sentences: 78
# Reading file: data/dataset/test.txt
# 100%|██████████| 13585/13585 [00:00<00:00, 525899.38it/s]
# number of sentences: 78
# #labels: 8
# label 2idx: {'<PAD>': 0, 'B-PHONE': 1, 'I-PHONE': 2, 'E-PHONE': 3, 'O': 4, 'S-PHONE': 5, '<START>': 6, '<STOP>': 7}
# Building the embedding table for vocabulary...
# [Info] Use the pretrained word embedding to initialize: 6796 x 300
# [Data Info] num chars: 175
# [Data Info] num words: 6796
# [Data Info] Removing 0% of entities from the training set
# [Data Info] Removing the entities
# [Training Info] number of training instances: 400
# [Training Info] The model will be saved to: english_model.tar.gz
# [Training Info] Running for 0th large iterations.
# [Training Info] Training fold 0.
# [Info] Building character-level LSTM
# [Model Info] Input size to LSTM: 350
# [Model Info] LSTM Hidden Size: 200
# [Model Info] Final Hidden Size: 200
# [Info] Adding IOBES constraints
# Using SGD: lr is: 0.001, L2 regularization is: 1e-08
# learning rate is set to:  0.001
# Epoch 1: 13513.92334, Time is 23.74s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# saving the best model...
# learning rate is set to:  0.001
# Epoch 2: -0.01611, Time is 23.82s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 3: 0.02832, Time is 23.95s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 4: -0.06250, Time is 23.78s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 5: 0.02148, Time is 23.63s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 6: -0.03076, Time is 23.70s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 7: 0.04492, Time is 23.65s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 8: -0.04492, Time is 23.64s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 9: 0.07568, Time is 23.58s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 10: -0.01758, Time is 23.71s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 11: 0.01855, Time is 23.64s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 12: 0.01904, Time is 23.69s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 13: 0.01270, Time is 23.72s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 14: -0.03662, Time is 23.49s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 15: 0.05371, Time is 23.44s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 16: -0.00586, Time is 23.91s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 17: -0.00439, Time is 23.55s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 18: -0.02734, Time is 23.49s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 19: 0.04736, Time is 23.62s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 20: 0.01660, Time is 23.53s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 21: 0.00830, Time is 23.65s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 22: -0.07568, Time is 23.63s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 23: 0.00391, Time is 23.61s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 24: 0.03857, Time is 23.58s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 25: 0.02637, Time is 23.47s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 26: 0.01123, Time is 23.56s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 27: -0.07910, Time is 23.45s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 28: -0.05371, Time is 23.76s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 29: 0.01709, Time is 23.54s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 30: 0.02051, Time is 23.31s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 31: 0.02637, Time is 23.40s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 32: -0.03174, Time is 23.52s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 33: 0.08691, Time is 23.39s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 34: -0.05811, Time is 23.37s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 35: 0.03564, Time is 23.44s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 36: 0.00391, Time is 23.35s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 37: 0.02344, Time is 23.23s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 38: -0.08447, Time is 23.53s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 39: 0.03906, Time is 23.27s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 40: 0.02686, Time is 23.45s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 41: -0.01367, Time is 23.46s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 42: 0.01660, Time is 23.30s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 43: 0.00049, Time is 23.25s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 44: 0.01953, Time is 23.36s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 45: -0.03271, Time is 23.25s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 46: -0.08887, Time is 23.32s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 47: -0.02197, Time is 23.32s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 48: -0.01855, Time is 23.42s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 49: 0.01416, Time is 23.24s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 50: -0.06738, Time is 23.35s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 51: 0.13428, Time is 23.44s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 52: -0.04102, Time is 23.49s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 53: -0.02783, Time is 23.48s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 54: 0.04883, Time is 23.51s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 55: 0.01904, Time is 23.44s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 56: -0.01416, Time is 23.32s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 57: 0.11963, Time is 23.45s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 58: 0.08105, Time is 23.32s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 59: -0.02197, Time is 23.32s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 60: 0.06494, Time is 23.14s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 61: -0.02002, Time is 22.84s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 62: -0.09766, Time is 23.01s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 63: -0.00732, Time is 22.94s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 64: 0.01611, Time is 23.14s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 65: -0.08057, Time is 23.61s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 66: 0.08447, Time is 23.50s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 67: -0.04248, Time is 23.55s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 68: -0.02148, Time is 23.18s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 69: 0.07422, Time is 23.15s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 70: -0.02734, Time is 23.07s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 71: -0.08398, Time is 23.01s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 72: -0.00146, Time is 22.89s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 73: 0.06396, Time is 23.13s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 74: 0.02051, Time is 22.93s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 75: 0.01074, Time is 22.87s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 76: 0.06104, Time is 23.09s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 77: 0.00732, Time is 23.15s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 78: -0.06445, Time is 22.97s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 79: -0.06348, Time is 22.88s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 80: 0.13916, Time is 22.86s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 81: -0.01855, Time is 22.80s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 82: -0.00977, Time is 22.80s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 83: 0.00342, Time is 23.09s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 84: 0.05029, Time is 22.73s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 85: -0.00342, Time is 22.80s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 86: 0.00586, Time is 22.88s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 87: -0.00635, Time is 22.80s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 88: 0.02002, Time is 22.74s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 89: -0.01221, Time is 22.80s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 90: 0.04492, Time is 22.97s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 91: -0.08154, Time is 22.76s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 92: 0.02979, Time is 22.74s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 93: 0.04297, Time is 22.80s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 94: 0.09082, Time is 22.84s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 95: 0.01709, Time is 22.82s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 96: -0.04053, Time is 23.66s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 97: 0.05469, Time is 23.95s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 98: -0.01221, Time is 23.15s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 99: -0.01904, Time is 22.93s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 100: 0.01172, Time is 22.87s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# [Training Info] Training fold 1.
# [Info] Building character-level LSTM
# [Model Info] Input size to LSTM: 350
# [Model Info] LSTM Hidden Size: 200
# [Model Info] Final Hidden Size: 200
# [Info] Adding IOBES constraints
# Using SGD: lr is: 0.001, L2 regularization is: 1e-08
# learning rate is set to:  0.001
# Epoch 1: 3906.20044, Time is 21.74s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# saving the best model...
# learning rate is set to:  0.001
# Epoch 2: 30.44482, Time is 21.98s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 3: 21.75098, Time is 21.85s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 4: 16.96875, Time is 21.64s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 5: 13.73096, Time is 21.89s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 6: 11.53857, Time is 21.92s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 7: 9.71143, Time is 22.00s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 8: 8.17871, Time is 22.05s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 9: 7.44678, Time is 21.87s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 10: 6.50879, Time is 21.72s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 11: 6.01904, Time is 21.70s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 12: 5.39844, Time is 21.66s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 13: 4.92285, Time is 21.80s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 14: 4.35547, Time is 21.77s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 15: 4.15771, Time is 21.77s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 16: 3.82568, Time is 21.99s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 17: 3.59277, Time is 21.66s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 18: 3.28076, Time is 21.72s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 19: 3.13379, Time is 21.81s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 20: 2.98584, Time is 21.84s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 21: 2.91357, Time is 21.92s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 22: 2.59717, Time is 22.01s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 23: 2.60352, Time is 22.24s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 24: 2.29785, Time is 22.04s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 25: 2.29639, Time is 21.84s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 26: 2.20215, Time is 21.87s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 27: 2.10889, Time is 21.56s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 28: 2.00928, Time is 21.64s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 29: 1.92920, Time is 21.95s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 30: 1.84668, Time is 21.74s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 31: 1.75098, Time is 21.70s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 32: 1.72998, Time is 21.63s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 33: 1.65186, Time is 21.86s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 34: 1.61572, Time is 21.64s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 35: 1.55908, Time is 21.60s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 36: 1.52734, Time is 21.73s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 37: 1.45508, Time is 21.76s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 38: 1.36865, Time is 21.63s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 39: 1.31885, Time is 21.66s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 40: 1.28564, Time is 21.86s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 41: 1.28418, Time is 21.59s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 42: 1.28076, Time is 21.89s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 43: 1.21582, Time is 21.81s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 44: 1.25391, Time is 21.76s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 45: 1.15576, Time is 21.65s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 46: 1.10254, Time is 21.66s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 47: 1.08984, Time is 21.80s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 48: 1.09912, Time is 21.58s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 49: 1.00928, Time is 21.65s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 50: 1.00977, Time is 21.82s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 51: 0.99463, Time is 21.63s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 52: 0.99561, Time is 21.63s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 53: 1.02148, Time is 21.74s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 54: 0.98877, Time is 21.65s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 55: 0.88916, Time is 21.86s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 56: 0.86133, Time is 21.64s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 57: 0.85645, Time is 21.88s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 58: 0.88281, Time is 21.63s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 59: 0.82227, Time is 21.50s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 60: 0.81885, Time is 21.71s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 61: 0.84766, Time is 21.62s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 62: 0.76855, Time is 21.58s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 63: 0.82324, Time is 21.69s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 64: 0.77490, Time is 21.84s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 65: 0.74561, Time is 21.70s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 66: 0.73975, Time is 21.36s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 67: 0.74512, Time is 21.53s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 68: 0.73535, Time is 22.55s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 69: 0.66943, Time is 22.26s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 70: 0.72119, Time is 21.98s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 71: 0.72217, Time is 21.85s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 72: 0.72070, Time is 21.67s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 73: 0.69971, Time is 21.68s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 74: 0.67480, Time is 21.71s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 75: 0.66064, Time is 21.54s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 76: 0.70898, Time is 21.62s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 77: 0.63184, Time is 21.74s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 78: 0.64844, Time is 21.58s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 79: 0.59570, Time is 21.58s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 80: 0.59229, Time is 21.66s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 81: 0.57959, Time is 21.88s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 82: 0.60791, Time is 21.59s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 83: 0.61377, Time is 21.66s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 84: 0.51367, Time is 21.80s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 85: 0.58350, Time is 21.59s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 86: 0.55811, Time is 21.38s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 87: 0.54590, Time is 21.40s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 88: 0.52832, Time is 21.83s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 89: 0.55078, Time is 21.59s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 90: 0.45850, Time is 21.38s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 91: 0.58691, Time is 21.60s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 92: 0.54053, Time is 21.43s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 93: 0.49658, Time is 21.42s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 94: 0.45020, Time is 21.60s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 95: 0.47607, Time is 21.76s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 96: 0.50000, Time is 21.42s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 97: 0.54492, Time is 21.45s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
# Epoch 98: 0.53711, Time is 22.68s
# [dev set] Precision: 0.00, Recall: 0.00, F1: 0.00
# learning rate is set to:  0.001
